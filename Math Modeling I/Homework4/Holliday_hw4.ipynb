# %% [markdown]
# Brian Holliday<br/>
# Professor Masuda<br/>
# Mathematical Modeling I<br/>
# 16 December 2019

# %% [markdown]
# ## Homework #4

# %%
load('newton.sage')

# %% [markdown]
# ### Problem 1

# %% [markdown]
# #### Part A

# %%
p(t) =.65*e^((.01/.65)*(-t))*(200 + 5*t) - .45*t

# %% [markdown]
# solve using global method

# %%
plot(p(t),13,14)
#We will use 13 as the initial answer to our newtons method and the maximum profit of 135.194
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
newton(p(t) - 135.194,13,100)
# Out:
# /ext/sage/sage-8.9_1804/local/lib/python2.7/site-packages/sage/repl/ipython_kernel/__main__.py:1: DeprecationWarning: Substitution using function-call syntax and unnamed arguments is deprecated and will be removed from a future release of Sage; you can use named arguments instead, like EXPR(x=..., y=...)
# See http://trac.sagemath.org/5930 for details.
#   from ipykernel.kernelapp import IPKernelApp
# 13.8151640544104

# %%
p(14)
# Out:
# 135.193591672095

# %% [markdown]
# We get that the pig should be sold after 14 days for maximum profit of 135.19 with newtons method

# %% [markdown]
# #### Part B

# %%
#Consider a %1 increase to price drop in the pig problem
.01 + 0.01*(.01)
# Out:
# 0.0101000000000000

# %%
p(t) =.65*e^((.0101/.65)*(-t))*(200 + 5*t) - .45*t

# %%
plot(p(t),13.2,15.0)
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [markdown]
# We will again use 13 as the starting point with newtons method

# %%
newton(p(t) - 134.94,13,100)
# Out:
# /ext/sage/sage-8.9_1804/local/lib/python2.7/site-packages/sage/repl/ipython_kernel/__main__.py:1: DeprecationWarning: Substitution using function-call syntax and unnamed arguments is deprecated and will be removed from a future release of Sage; you can use named arguments instead, like EXPR(x=..., y=...)
# See http://trac.sagemath.org/5930 for details.
#   from ipykernel.kernelapp import IPKernelApp
# 11.0974896359570

# %%
p(13)
# Out:
# 134.894601338050

# %% [markdown]
# We could say that the maximum profit happens on day 13 this time with a profit of  134.90

# %% [markdown]
# Sensitivity analysis of the price drop rate to profit

# %% [markdown]
# We will use the percent difference formula to see the difference in the day value and find the sensitivity

# %%
(13.815 - 12.309)*100/((13.815 + 12.309)/2)
# Out:
# 11.5296279283418

# %% [markdown]
# We see that a one percent increase in the pig drop rate makes the profit time decrease by 11.53 percent

# %% [markdown]
# ### Problem 2

# %%
p(t) =(.65 - .01*t + .00004*t**2)*(200 + 5*t) - .45*t

# %%
show(p)
# Out:
# t |--> 5*(0.0000400000000000000*t^2 - 0.0100000000000000*t + 0.650000000000000)*(t + 40) - 0.450000000000000*t

# %%
plot(p(t),10,11)
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [markdown]
# 10 days seems to be the optimal time to sell the pig with a profit of 134. Lets comfirm this with newtons method

# %%
newton(p(t) - 134.005,10,100)
# Out:
# /ext/sage/sage-8.9_1804/local/lib/python2.7/site-packages/sage/repl/ipython_kernel/__main__.py:1: DeprecationWarning: Substitution using function-call syntax and unnamed arguments is deprecated and will be removed from a future release of Sage; you can use named arguments instead, like EXPR(x=..., y=...)
# See http://trac.sagemath.org/5930 for details.
#   from ipykernel.kernelapp import IPKernelApp
# 10.2568626702032

# %%
p(11)
# Out:
# 133.984200000000

# %% [markdown]
# Newtons method confirms that we should sell the pig at day 11

# %% [markdown]
# If we increase the rate at which the price is leveling off by 1 percent we can get its sensitivity

# %%
.00004 + (.01)*.0004
#we will substitute this in our original equation
# Out:
# 0.0000440000000000000

# %%
p(t) =(.65 - .01*t + .000044*t**2)*(200 + 5*t) - .45*t

# %%
plot(p(t),9,12)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
newton(p(t) - 134.115,10,100)
# Out:
# /ext/sage/sage-8.9_1804/local/lib/python2.7/site-packages/sage/repl/ipython_kernel/__main__.py:1: DeprecationWarning: Substitution using function-call syntax and unnamed arguments is deprecated and will be removed from a future release of Sage; you can use named arguments instead, like EXPR(x=..., y=...)
# See http://trac.sagemath.org/5930 for details.
#   from ipykernel.kernelapp import IPKernelApp
# 10.4325818312514

# %% [markdown]
# We see again the pig should be sold by day 11

# %%
p(11)
# Out:
# 134.107620000000

# %%
(10.4325818312514 - 10.2568626702032)/((10.4325818312514 + 10.2568626702032)/2)
# Out:
# 0.0169863585303941

# %% [markdown]
# We see that If we increase the rate at which the price is leveling off by 1 percent the time to sell the pig goes up by about 1.7 percent

# %%
(134.107620000000 - 133.984200000000)/((134.107620000000 + 133.984200000000)/2)
# Out:
# 0.000920729323259547

# %%
0.000920729323259547 * 100
# Out:
# 0.0920729323259547

# %% [markdown]
# We see that If we increase the rate at which the price is leveling off by 1 percent the profit of the pig goes up by about 0.09207 percent
